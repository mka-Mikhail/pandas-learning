# %%
import pandas as pd
import sqlite3

# %%
con = sqlite3.connect('weather_2012.sqlite')

# %%
df = pd.read_sql('SELECT * from weather_2012 LIMIT 3', con)
df
# Out:
#    id            date_time  temp
# 0   1  2012-01-01 00:00:00  -1.8
# 1   2  2012-01-01 01:00:00  -1.8
# 2   3  2012-01-01 02:00:00  -1.8

# %%
df = pd.read_sql("SELECT * from weather_2012 LIMIT 3", con, index_col='id')
df
# Out:
#               date_time  temp
# id
# 1   2012-01-01 00:00:00  -1.8
# 2   2012-01-01 01:00:00  -1.8
# 3   2012-01-01 02:00:00  -1.8

# %%
weather_df = pd.read_csv('weather_2012.csv')
con = sqlite3.connect('test_db.sqlite')
con.execute('DROP TABLE IF EXISTS weather_2012')
weather_df.to_sql('weather_2012', con)
# Out:
# 8784

# %%
df = pd.read_sql('SELECT * from weather_2012 LIMIT 3', con)
df
# Out:
#    index      Date/Time (LST)  Longitude (x)  Latitude (y)  \
# 0      0  2012-01-01 00:00:00         -73.75         45.47
# 1      1  2012-01-01 01:00:00         -73.75         45.47
# 2      2  2012-01-01 02:00:00         -73.75         45.47
#
#                              Station Name  Climate ID  Temp (°C)  \
# 0  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A     7025250       -1.8
# 1  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A     7025250       -1.8
# 2  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A     7025250       -1.8
#
#    Dew Point Temp (°C)  Rel Hum (%)  Wind Spd (km/h)  Visibility (km)  \
# 0                 -3.9           86                4              8.0
# 1                 -3.7           87                4              8.0
# 2                 -3.4           89                7              4.0
#
#    Stn Press (kPa)               Weather
# 0           101.24                   Fog
# 1           101.24                   Fog
# 2           101.26  Freezing Drizzle,Fog

# %%
df = pd.read_sql('SELECT * from weather_2012 ORDER BY Weather LIMIT 3', con)
df
# Out:
#    index      Date/Time (LST)  Longitude (x)  Latitude (y)  \
# 0     67  2012-01-03 19:00:00         -73.75         45.47
# 1    114  2012-01-05 18:00:00         -73.75         45.47
# 2    115  2012-01-05 19:00:00         -73.75         45.47
#
#                              Station Name  Climate ID  Temp (°C)  \
# 0  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A     7025250      -16.9
# 1  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A     7025250       -7.1
# 2  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A     7025250       -9.2
#
#    Dew Point Temp (°C)  Rel Hum (%)  Wind Spd (km/h)  Visibility (km)  \
# 0                -24.8           50               24             25.0
# 1                -14.4           56               11             25.0
# 2                -15.4           61                7             25.0
#
#    Stn Press (kPa) Weather
# 0           101.74   Clear
# 1           100.71   Clear
# 2           100.80   Clear
